# %%
# !pip install pandas
# Out:
# Access is denied.

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Prapti Pramanik\Downloads\archive.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df["ExerciseAngina"].value_counts()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64

# %%
# !pip install numpy
# Out:
# Access is denied.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.pairplot(data=df)
plt.show()

# %%
x=df.iloc[:,:-1]

# %%
y=df["HeartDisease"]

# %%
x
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in x.select_dtypes(include=['object']).columns:
    x[i]=le.fit_transform(x[i])

# %%
x
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 712   58    1              0        100          234          0           1
# 477   61    1              0        110            0          1           1
# 409   53    1              2        160            0          1           0
# 448   63    1              0        160          230          1           1
# 838   63    1              0        130          330          1           0
# ..   ...  ...            ...        ...          ...        ...         ...
# 106   48    0              0        120          254          0           2
# 270   45    1              0        120          225          0           1
# 860   60    1              0        130          253          0           1
# 435   60    1              0        152            0          0           2
# 102   40    0              0        150          392          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_test
# Out:
# array([[ 1.03853914, -2.23606798,  0.13699588, ..., -0.80789517,
#         -0.87183724,  1.02309102],
#        [-0.03179993,  0.4472136 ,  1.13201859, ..., -0.80789517,
#         -0.87183724, -0.55441245],
#        [ 1.25260696,  0.4472136 , -0.85802683, ..., -0.80789517,
#          0.36744385, -0.55441245],
#        ...,
#        [ 0.28930179,  0.4472136 , -0.85802683, ...,  1.23778435,
#          0.78053755, -2.13191592],
#        [ 0.93150524,  0.4472136 ,  1.13201859, ...,  1.23778435,
#         -0.87183724, -0.55441245],
#        [ 0.50336961, -2.23606798,  1.13201859, ..., -0.80789517,
#         -0.87183724,  1.02309102]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train),lr.score(x_test,y_test)
# Out:
# (0.8535825545171339, 0.8623188405797102)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='rbf')

# %%
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
svc.score(x_train,y_train),svc.score(x_test,y_test)
# Out:
# (0.8925233644859814, 0.8913043478260869)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(x_train,y_train),knn.score(x_test,y_test)
# Out:
# (0.8956386292834891, 0.8514492753623188)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc=DecisionTreeClassifier(max_depth=7)
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
dc.score(x_train,y_train),dc.score(x_test,y_test)
# Out:
# (0.9376947040498442, 0.7789855072463768)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=50,max_depth=20,class_weight={0:1,1:5})
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight={0: 1, 1: 5}, max_depth=20, n_estimators=50)

# %%
rf.score(x_train,y_train),rf.score(x_test,y_test)
# Out:
# (1.0, 1.0)

# %%
y_pred1 = rf.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 1.0
